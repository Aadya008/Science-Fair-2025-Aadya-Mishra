# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Science Fair 2025 Data Document - IV_Impurities.csv')

# %%
df.head(15)
# Out:
#    Trial #                                Senario  PM2.5  PM1.0  PM10   HCHO  \
# 0        1         Candle added to add IMPURITIES     48     31    60  0.008
# 1        2         Candle added to add IMPURITIES     39     26    47  0.005
# 2        3         Candle added to add IMPURITIES     34     34    40  0.006
# 3        4  Incense Stick added to add IMPURITIES    999    159   999  1.000
# 4        5  Incense Stick added to add IMPURITIES    999    142   999  1.000
# 5        6  Incense Stick added to add IMPURITIES    999    130   999  1.000
# 6        7    Match Stick added to add IMPURITIES    999    346   999  0.619
# 7        8    Match Stick added to add IMPURITIES    999    344   999  0.606
# 8        9    Match Stick added to add IMPURITIES    999    342   999  0.596
# 9       10    Match Stick added to add IMPURITIES    999    343   999  0.589
#
#     TVOC  AQI  Temperature  Humidity
# 0  0.026    1         25.4        35
# 1  0.019    1         25.8        45
# 2  0.046    1         26.2        51
# 3  5.000    6         27.6        26
# 4  5.000    6         27.7        26
# 5  5.000    6         27.9        26
# 6  4.736    6         27.1        35
# 7  4.612    6         27.1        35
# 8  4.534    6         27.1        35
# 9  4.478    6         27.1        35

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Trial #      10 non-null     int64
#  1   Senario      10 non-null     object
#  2   PM2.5        10 non-null     int64
#  3   PM1.0        10 non-null     int64
#  4   PM10         10 non-null     int64
#  5   HCHO         10 non-null     float64
#  6   TVOC         10 non-null     float64
#  7   AQI          10 non-null     int64
#  8   Temperature  10 non-null     float64
#  9   Humidity     10 non-null     int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 928.0+ bytes

# %%
df.describe()
# Out:
#         Trial #       PM2.5       PM1.0        PM10       HCHO       TVOC  \
# count  10.00000   10.000000   10.000000   10.000000  10.000000  10.000000
# mean    5.50000  711.400000  189.700000  714.000000   0.542900   3.345100
# std     3.02765  463.092071  140.610613  458.918535   0.408963   2.295311
# min     1.00000   34.000000   26.000000   40.000000   0.005000   0.019000
# 25%     3.25000  285.750000   58.000000  294.750000   0.153250   1.154000
# 50%     5.50000  999.000000  150.500000  999.000000   0.601000   4.573000
# 75%     7.75000  999.000000  342.750000  999.000000   0.904750   4.934000
# max    10.00000  999.000000  346.000000  999.000000   1.000000   5.000000
#
#              AQI  Temperature   Humidity
# count  10.000000    10.000000  10.000000
# mean    4.500000    26.900000  34.900000
# std     2.415229     0.832666   8.157478
# min     1.000000    25.400000  26.000000
# 25%     2.250000    26.425000  28.250000
# 50%     6.000000    27.100000  35.000000
# 75%     6.000000    27.475000  35.000000
# max     6.000000    27.900000  51.000000

# %%
df.columns
# Out:
# Index(['Trial #', 'Senario', 'PM2.5', 'PM1.0', 'PM10', 'HCHO', 'TVOC', 'AQI',
#        'Temperature', 'Humidity'],
#       dtype='object')

# %%
df.shape
# Out:
# (10, 10)

# %%
df.count()
# Out:
# Trial #        10
# Senario        10
# PM2.5          10
# PM1.0          10
# PM10           10
# HCHO           10
# TVOC           10
# AQI            10
# Temperature    10
# Humidity       10
# dtype: int64

# %%
df.isna().sum()
# Out:
# Trial #        0
# Senario        0
# PM2.5          0
# PM1.0          0
# PM10           0
# HCHO           0
# TVOC           0
# AQI            0
# Temperature    0
# Humidity       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(x='Senario',y='PM2.5',data=df)
plt.title('PM2.5 Vs Impurities')
plt.xlabel('Candle | Inscent Stick | Match Stick')
plt.ylabel('PM2.5 (ug/m^3)')
# Out:
# Text(0, 0.5, 'PM2.5 (ug/m^3)')

# %%
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(x='Senario',y='PM1.0',data=df)
plt.title('PM1.0 Vs Impurities')
plt.xlabel('Candle | Inscent Stick | Match Stick')
plt.ylabel('PM1.0 (ug/m^3)')
# Out:
# Text(0, 0.5, 'PM1.0 (ug/m^3)')

# %%
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(x='Senario',y='PM10',data=df)
plt.title('PM10 Vs Impurities')
plt.xlabel('Candle | Inscent Stick | Match Stick')
plt.ylabel('PM10 (ug/m^3)')
# Out:
# Text(0, 0.5, 'PM10 (ug/m^3)')

# %%
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(x='Senario',y='TVOC',data=df)
plt.title('TVOC Vs Impurities')
plt.xlabel('Candle | Inscent Stick | Match Stick')
plt.ylabel('TVOC (total volatile organic compounds) mg/m^3')
# Out:
# Text(0, 0.5, 'TVOC (total volatile organic compounds) mg/m^3')

# %%
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(x='Senario',y='HCHO',data=df)
plt.title('HCHO Vs Impurities')
plt.xlabel('Candle | Inscent Stick | Match Stick')
plt.ylabel('HCHO (formaldehyde) (mg/m^3)')
# Out:
# Text(0, 0.5, 'HCHO (formaldehyde) (mg/m^3)')
