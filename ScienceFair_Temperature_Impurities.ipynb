# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Science Fair 2025 Data Document - IV_Temperature_Impurities.csv')

# %%
df.head(15)
# Out:
#    Trial #                                            Senario  PM2.5  PM1.0  \
# 0        1  Candle with Ice Cubes for a change in TEMPERAT...     34     23
# 1        2  Candle with Ice Cubes for a change in TEMPERAT...     34     21
# 2        3  Candle with Ice Cubes for a change in TEMPERAT...     32     21
# 3        4  Candle with Ice Cubes for a change in TEMPERAT...     30     20
# 4        5  Incense with Ice Cubes for a change in TEMPERA...    999    336
# 5        6  Incense with Ice Cubes for a change in TEMPERA...    999    341
# 6        7  Incense with Ice Cubes for a change in TEMPERA...    999    350
# 7        8  Match with Ice Cubes for a change in TEMPERATU...    999    366
# 8        9  Match with Ice Cubes for a change in TEMPERATU...    999    365
# 9       10  Match with Ice Cubes for a change in TEMPERATU...    999    356
#
#    PM10   HCHO   TVOC  AQI  Temperature  Humidity
# 0    41  0.109  0.730    3         27.3        29
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Trial #      10 non-null     int64
#  1   Senario      10 non-null     object
#  2   PM2.5        10 non-null     int64
#  3   PM1.0        10 non-null     int64
#  4   PM10         10 non-null     int64
#  5   HCHO         10 non-null     float64
#  6   TVOC         10 non-null     float64
#  7   AQI          10 non-null     int64
#  8   Temperature  10 non-null     float64
#  9   Humidity     10 non-null     int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 928.0+ bytes

# %%
df.describe()
# Out:
#         Trial #       PM2.5      PM1.0        PM10      HCHO       TVOC  \
# count  10.00000   10.000000   10.00000   10.000000  10.00000  10.000000
# mean    5.50000  612.400000  219.90000  614.200000   0.52370   3.137800
# std     3.02765  499.099678  171.21945  496.778019   0.39776   2.134174
# min     1.00000   30.000000   20.00000   34.000000   0.09900   0.659000
# 25%     3.25000   34.000000   21.50000   38.750000   0.10600   0.715000
# 50%     5.50000  999.000000  338.50000  999.000000   0.56950   4.307000
# 75%     7.75000  999.000000  354.50000  999.000000   0.92125   5.000000
# max    10.00000  999.000000  366.00000  999.000000   1.00000   5.000000
#
#              AQI  Temperature   Humidity
# count  10.000000    10.000000  10.000000
# mean    4.800000    26.960000  29.900000
# std     1.549193     0.419524   2.960856
# min     3.000000    26.300000  26.000000
# 25%     3.000000    26.625000  26.750000
# 50%     6.000000    27.000000  31.000000
# ...

# %%
df.columns
# Out:
# Index(['Trial #', 'Senario', 'PM2.5', 'PM1.0', 'PM10', 'HCHO', 'TVOC', 'AQI',
#        'Temperature', 'Humidity'],
#       dtype='object')

# %%
df.shape
# Out:
# (10, 10)

# %%
df.count()
# Out:
# Trial #        10
# Senario        10
# PM2.5          10
# PM1.0          10
# PM10           10
# HCHO           10
# TVOC           10
# AQI            10
# Temperature    10
# Humidity       10
# dtype: int64

# %%
df.isna().sum()
# Out:
# Trial #        0
# Senario        0
# PM2.5          0
# PM1.0          0
# PM10           0
# HCHO           0
# TVOC           0
# AQI            0
# Temperature    0
# Humidity       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(x='Senario',y='PM2.5',data=df)
plt.title('PM2.5 Vs Impurities')
plt.xlabel('Candle | Inscent Stick | Match Stick')
plt.ylabel('PM2.5 (ug/m^3)')
# Out:
# Text(0, 0.5, 'PM2.5 (ug/m^3)')

# %%
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(x='Senario',y='PM1.0',data=df)
plt.title('PM1.0 Vs Impurities')
plt.xlabel('Candle | Inscent Stick | Match Stick')
plt.ylabel('PM1.0 (ug/m^3)')
# Out:
# Text(0, 0.5, 'PM1.0 (ug/m^3)')

# %%
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(x='Senario',y='PM10',data=df)
plt.title('PM10 Vs Impurities')
plt.xlabel('Candle | Inscent Stick | Match Stick')
plt.ylabel('PM10 (ug/m^3)')
# Out:
# Text(0, 0.5, 'PM10 (ug/m^3)')

# %%
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(x='Senario',y='TVOC',data=df)
plt.title('TVOC Vs Impurities')
plt.xlabel('Candle | Inscent Stick | Match Stick')
plt.ylabel('TVOC (total volatile organic compounds) mg/m^3')
# Out:
# Text(0, 0.5, 'TVOC (total volatile organic compounds) mg/m^3')

# %%
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(x='Senario',y='HCHO',data=df)
plt.title('HCHO Vs Impurities')
plt.xlabel('Candle | Inscent Stick | Match Stick')
plt.ylabel('HCHO (formaldehyde) (mg/m^3)')
# Out:
# Text(0, 0.5, 'HCHO (formaldehyde) (mg/m^3)')
